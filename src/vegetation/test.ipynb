# %%
ko=0.248 
kc=0.000404

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
Resp = 10*(10**-6)
TFREEZE = 273
a = [1 / ((1.0+np.exp(0.4*(5.0-tl+TFREEZE))) \
                   * (1.0+np.exp(0.4*(tl-45.0-TFREEZE)))) for tl in np.arange(273+0,273+30)]

# %%
plt.scatter(np.arange(273+0,273+30),a)
